# %%
# importando pandas as pd
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv('tmdb_5000_movies.csv',sep=',')

# %%
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df.shape
# Out:
# (4803, 20)

# %%
df['original_language'].unique() #Variavel categórica
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
#quantidade de votos -> 1,2,3,4,5
#budget -> quantidade continua

# %% [markdown]
# # Variáveis Quantitativas: são as características que podem ser medidas em uma escala quantitativa, ou seja, apresentam valores numéricos que fazem sentido. Podem ser contínuas ou discretas.
# Variáveis discretas: características mensuráveis que podem assumir apenas um número finito ou infinito contável de valores e, assim, somente fazem sentido valores inteiros. Geralmente são o resultado de contagens. Exemplos: número de filhos, número de bactérias por litro de leite, número de cigarros fumados por dia.
# Variáveis contínuas, características mensuráveis que assumem valores em uma escala contínua (na reta real), para as quais valores fracionais fazem sentido. Usualmente devem ser medidas através de algum instrumento. Exemplos: peso (balança), altura (régua), tempo (relógio), pressão arterial, idade.
# Variáveis Qualitativas (ou categóricas): são as características que não possuem valores quantitativos, mas, ao contrário, são definidas por várias categorias, ou seja, representam uma classificação dos indivíduos. Podem ser nominais ou ordinais.
# Variáveis nominais: não existe ordenação dentre as categorias. Exemplos: sexo, cor dos olhos, fumante/não fumante, doente/sadio.
# Variáveis ordinais: existe uma ordenação entre as categorias. Exemplos: escolaridade (1o, 2o, 3o graus), estágio da doença (inicial, intermediário, terminal), mês de observação (janeiro, fevereiro,..., dezembro).

# %%
df['original_language'].value_counts() #conta a quantidade de valores
# Out:
# en    4505
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# cn      12
# ru      11
# ko      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# ta       2
# cs       2
# ro       2
# id       2
# ar       2
# vi       1
# sl       1
# ps       1
# no       1
# ky       1
# hu       1
# pl       1
# af       1
# nb       1
# tr       1
# is       1
# xx       1
# te       1
# el       1
# Name: original_language, dtype: int64

# %%
df['original_language'].value_counts().to_frame().reset_index()
# Out:
#    index  original_language
# 0     en               4505
# 1     fr                 70
# 2     es                 32
# 3     zh                 27
# 4     de                 27
# 5     hi                 19
# 6     ja                 16
# 7     it                 14
# 8     cn                 12
# 9     ru                 11
# 10    ko                 11
# 11    pt                  9
# 12    da                  7
# 13    sv                  5
# 14    nl                  4
# 15    fa                  4
# 16    th                  3
# 17    he                  3
# 18    ta                  2
# 19    cs                  2
# 20    ro                  2
# 21    id                  2
# 22    ar                  2
# 23    vi                  1
# 24    sl                  1
# 25    ps                  1
# 26    no                  1
# 27    ky                  1
# 28    hu                  1
# 29    pl                  1
# 30    af                  1
# 31    nb                  1
# ...

# %%
contagem_lingua = df['original_language'].value_counts()

# %%
contagem_lingua
# Out:
# en    4505
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# cn      12
# ru      11
# ko      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# ta       2
# cs       2
# ro       2
# id       2
# ar       2
# vi       1
# sl       1
# ps       1
# no       1
# ky       1
# hu       1
# pl       1
# af       1
# nb       1
# tr       1
# is       1
# xx       1
# te       1
# el       1
# Name: original_language, dtype: int64

# %%
contagem_lingua=df.original_language.value_counts().reset_index()

# %%
contagem_lingua.columns=['lingua','total']

# %%
contagem_lingua.head()
# Out:
#   lingua  total
# 0     en   4505
# 1     fr     70
# 2     es     32
# 3     zh     27
# 4     de     27

# %%
contagem_lingua.head()
# Out:
#   lingua  total
# 0     en   4505
# 1     fr     70
# 2     es     32
# 3     zh     27
# 4     de     27

# %%
sns.barplot(x="lingua",y= "total",data = contagem_lingua)
# Out:
# <AxesSubplot:xlabel='lingua', ylabel='total'>

# %%
sns.catplot(x='original_language',kind='count',data = df)

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(contagem_lingua['total'],labels=contagem_lingua['lingua'])
# Out:
# ([<matplotlib.patches.Wedge at 0x2021da9dc60>,
# ...
#  [Text(-1.0791697536499925, 0.2130554923183512, 'en'),
#   Text(1.0355355017029462, -0.3710339940124459, 'fr'),
#   Text(1.0579676486019882, -0.3011718023181785, 'es'),
#   Text(1.0687996606645356, -0.26012936274741094, 'zh'),
#   Text(1.0773191105706255, -0.22222406260195313, 'de'),
#   Text(1.0835167978583342, -0.18971386021801853, 'hi'),
#   Text(1.0875756432724297, -0.16486121484618815, 'ja'),
#   Text(1.0906010773146022, -0.14348968659882622, 'it'),
#   Text(1.092883487371409, -0.12492270822755745, 'cn'),
#   Text(1.0946390911069936, -0.10846778425161549, 'ru'),
#   Text(1.0960865535188649, -0.09270527058984593, 'ko'),
#   Text(1.0972054830031333, -0.07835896928789601, 'pt'),
#   Text(1.097965443340663, -0.06687215586282344, 'da'),
#   Text(1.0984565010300316, -0.05825217030171998, 'sv'),
#   Text(1.0987803851616647, -0.0517847968421653, 'nl'),
#   Text(1.0990363161210686, -0.04603450713357274, 'fa'),
# ...

# %%
total_por_lingua=df['original_language'].value_counts()
total_geral = total_por_lingua.sum()
total_ingles=total_por_lingua.loc["en"]
resto = total_geral - total_ingles
print(f'Total ingles: {total_ingles}, total restante: { resto}')
# Out:
# Total ingles: 4505, total restante: 298

# %%
#Cria um dicionario para criar outro dataframe
dados = {
    'lingua':['ingles','outros'],
    'total': [total_ingles,resto]
}

# %%
dados
# Out:
# {'lingua': ['ingles', 'outros'], 'total': [4505, 298]}

# %%
#cria dataframe

# %%
dados =pd.DataFrame(dados)

# %%
sns.barplot(x='lingua',y='total',data = dados)
# Out:
# <AxesSubplot:xlabel='lingua', ylabel='total'>

# %%
plt.pie(dados["total"], labels = dados["lingua"])
# Out:
# ([<matplotlib.patches.Wedge at 0x2020aec8ca0>,
# ...
#  [Text(-1.0791697536499925, 0.2130554923183512, 'ingles'),
#   Text(1.0791697511565306, -0.2130555049482467, 'outros')])

# %%
total_lingua_outros = df.query("original_language !='en'").original_language.value_counts().to_frame().reset_index()

# %%
total_lingua_outros = df.query("original_language !='en'")

# %%
total_lingua_outros.head()
# Out:
#        budget                                             genres  \
# 97   15000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 235  97250400  [{"id": 14, "name": "Fantasy"}, {"id": 12, "na...
# 317  94000000  [{"id": 18, "name": "Drama"}, {"id": 36, "name...
# 474         0  [{"id": 9648, "name": "Mystery"}, {"id": 18, "...
# 492   8000000  [{"id": 35, "name": "Comedy"}, {"id": 16, "nam...
#
#                                               homepage      id  \
# 97                                                 NaN  315011
# 235  http://www.asterixauxjeuxolympiques.com/index.php    2395
# 317               http://www.theflowersofwarmovie.com/   76758
# 474                                                NaN  330770
# 492                                                NaN  293644
#
#                                               keywords original_language  \
# 97   [{"id": 1299, "name": "monster"}, {"id": 7671,...                ja
# ...

# %%
sns.catplot(x = 'original_language', data = total_lingua_outros,kind='count')

# %%
filmes_outros =  df.query("original_language !='en'").original_language.value_counts()

# %%
sns.catplot(x = 'original_language', kind='count',data = total_lingua_outros,aspect=2)

# %%
sns.catplot(x = 'original_language', kind='count',data = total_lingua_outros,aspect=2,palette="GnBu_d",order = filmes_outros.index)

# %%
sns.set(style="ticks")

# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# %% [markdown]
# #Revisando o papel da media, mediana, medidas de tendencia central
